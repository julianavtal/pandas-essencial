# %% [markdown]
# <a href="https://colab.research.google.com/github/julianavtal/pandas-essencial/blob/main/manipulacao_de_dados_codigo_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
import google.colab.drive as drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Data Science 2025 IFSP/datasets/GasPricesinBrazil_2004-2019.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science 2025 IFSP/datasets/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
df.head(1)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                  1.35
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
#
# [1 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
#função info() explica os tipos de dado pra cada uma das colunas
#tipo 'object' no geral representa strings

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
#dúvida conceitual: o que é um atributo em py? o que é um método? qual a diferença pra uma função
df.shape

#o resultado é uma tupla, podemos acessar por index
# Out:
# (106823, 21)

# %%
#o f' funciona para usarmos {} e não precisar concatenar strings
# usar o \n para pular pra próxima linha

print(f'número de linhas: {df.shape[0]} \nnúmero de colunas: {df.shape[1]}')
# Out:
# número de linhas: 106823
# número de colunas: 21

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
#criando um df a partir de um dicionário
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15, 60],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O atributo `DataFrame.columns` retorna uma "lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(personagens_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#transformando as colunas em uma lista
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
#para renomear, passamos um dicionário

personagens_df.rename(columns = {
                    'nome' : "Nome"
                    ,"idade" : "Idade"
                    ,'peso' : 'Peso'
                    ,'eh jedi' : 'É Jedi?'

                    })
# Out:
#              Nome  Idade  Peso  É Jedi?
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
#para as mudanças serem salvas no df, necessário usar o inplace
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
#usando inplace para salvar as mudanças no df

personagens_df.rename(columns = {
                    'nome' : "Nome"
                    ,"idade" : "Idade"
                    ,'peso' : 'Peso'
                    ,'eh jedi' : 'É Jedi?'

                    }, inplace = True)

# %%
personagens_df
# Out:
#              Nome  Idade  Peso  É Jedi?
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
#para arrumar todas de uma vez, por exemplo todas para minusculas
personagens_df.columns = map(str.lower, personagens_df.columns)
personagens_df
# Out:
#              nome  idade  peso  é jedi?
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
#outra maneira de renomear as colunas é passando os novos nomes via lista
#ou seja precisa ter o mesmo numero de elementos (mesmo número de valores para um número de colunas)

personagens_df.columns = ['Nome', 'Idade','Peso', 'É jedi?']
personagens_df
# Out:
#              Nome  Idade  Peso  É jedi?
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
#quando é lista, ele já salva automaticamente
personagens_df
# Out:
#              Nome  Idade  Peso  É jedi?
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
#exemplo com mismatch = menos valores do que colunas identificadas

#personagens_df.columns = ['Nome', 'Idade','Peso']
#personagens_df

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
#selecionando uma coluna toda

df['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
#dúvida: como selecionar determinadas colunas desse jeito?

#ex: df['ESTADO', 'PRODUTO']

# %%
#usando head() em uma coluna
df['ESTADO'].head()
# Out:
# 0      DISTRITO FEDERAL
# 1                 GOIAS
# 2           MATO GROSSO
# 3    MATO GROSSO DO SUL
# 4               ALAGOAS
# Name: ESTADO, dtype: object

# %%
#outra forma de chamar a coluna
#essa forma só funciona pra nomes de coluna sem espaço, caracteres especiais e etc
#aqui é criado um atributo, por isso não pode ter caracteres inválidos
df.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
#outra forma de chamar a coluna e usando head()
df.ESTADO.head()
# Out:
# 0      DISTRITO FEDERAL
# 1                 GOIAS
# 2           MATO GROSSO
# 3    MATO GROSSO DO SUL
# 4               ALAGOAS
# Name: ESTADO, dtype: object

# %%
#da outra maneira
type(df['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
#como chamar mais de uma coluna dessa maneira?

# %%
#informações sobre uma coluna
type(df.ESTADO)
# Out:
# pandas.core.series.Series

# %%
#todos os valores da linha 1

df.iloc[1]

#type sai como 'object' porque existem dados de múltiplos tipos
#dúvida: então o que exatamente é o object?

#importante: com a extração de 1 linha, os índices das colunas são a ordem das colunas (pivot)
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([1.1,3.0,5.2])
# Out:
# 0    1.1
# 1    3.0
# 2    5.2
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([1.1,3.0,5.2], index = ['3º colocado', '2º colocado', '1º colocado'])
# Out:
# 3º colocado    1.1
# 2º colocado    3.0
# 1º colocado    5.2
# dtype: float64

# %%
#dando um nome pra coluna

pd.Series([1.1,3.0,5.2], index = ['3º colocado', '2º colocado', '1º colocado'], name = 'Posição')
# Out:
# 3º colocado    1.1
# 2º colocado    3.0
# 1º colocado    5.2
# Name: Posição, dtype: float64

# %%
#classificar como desc
s = pd.Series([1.1,3.0,5.2], index = ['3º colocado', '2º colocado', '1º colocado'])

s.sort_values(ascending=False)
# Out:
# 1º colocado    5.2
# 2º colocado    3.0
# 3º colocado    1.1
# dtype: float64

# %%
#pra salvar, precisa usar o inplace = True
s
# Out:
# 3º colocado    1.1
# 2º colocado    3.0
# 1º colocado    5.2
# dtype: float64

# %%
#pra salvar, precisa usar o inplace = True
s.sort_values(ascending=False, inplace=True)
s
# Out:
# 1º colocado    5.2
# 2º colocado    3.0
# 3º colocado    1.1
# dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
df['PRODUTO'] #o retorno não é a coluna em si (uma cópia, uma view), mas sim uma referência à coluna
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
#para criar uma cópia, necessário usar o .copy()
df['PRODUTO'].copy()
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
#salvando como uma variável

df_produto = df['PRODUTO'].copy()

# %%
#se quiser apenas as primeiras linhas
df_produto_head5 = df['PRODUTO'].copy().head()
df_produto_head5
# Out:
# 0    ETANOL HIDRATADO
# 1    ETANOL HIDRATADO
# 2    ETANOL HIDRATADO
# 3    ETANOL HIDRATADO
# 4    ETANOL HIDRATADO
# Name: PRODUTO, dtype: object

# %%
#podemos passar um valor constante para toda a coluna
df['PRODUTO'] = 'Combustível'
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
#recuperando os valores de 'PRODUTO'
df_produto
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
df.shape
# Out:
# (106823, 21)

# %%
nrows = df.shape[0]
nrows
# Out:
# 106823

# %%
nrows, ncols = df.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
produtos_numerados = [f'Produto {i}' for i in range(nrows)]
produtos_numerados
# Out:
# ['Produto 0',
#  'Produto 1',
#  'Produto 2',
#  'Produto 3',
#  'Produto 4',
#  'Produto 5',
#  'Produto 6',
#  'Produto 7',
#  'Produto 8',
#  'Produto 9',
#  'Produto 10',
#  'Produto 11',
#  'Produto 12',
#  'Produto 13',
#  'Produto 14',
#  'Produto 15',
#  'Produto 16',
#  'Produto 17',
#  'Produto 18',
#  'Produto 19',
#  'Produto 20',
#  'Produto 21',
#  'Produto 22',
#  'Produto 23',
#  'Produto 24',
#  'Produto 25',
#  'Produto 26',
#  'Produto 27',
#  'Produto 28',
#  'Produto 29',
#  'Produto 30',
#  'Produto 31',
#  'Produto 32',
#  'Produto 33',
#  'Produto 34',
#  'Produto 35',
#  'Produto 36',
#  'Produto 37',
#  'Produto 38',
#  'Produto 39',
#  'Produto 40',
#  'Produto 41',
#  'Produto 42',
#  'Produto 43',
#  'Produto 44',
#  'Produto 45',
#  'Produto 46',
#  'Produto 47',
#  'Produto 48',
#  'Produto 49',
#  'Produto 50',
#  'Produto 51',
#  'Produto 52',
#  'Produto 53',
#  'Produto 54',
#  'Produto 55',
#  'Produto 56',
#  'Produto 57',
#  'Produto 58',
#  'Produto 59',
#  'Produto 60',
#  'Produto 61',
#  'Produto 62',
#  'Produto 63',
#  'Produto 64',
#  'Produto 65',
#  'Produto 66',
#  'Produto 67',
#  'Produto 68',
#  'Produto 69',
#  'Produto 70',
#  'Produto 71',
#  'Produto 72',
#  'Produto 73',
#  'Produto 74',
#  'Produto 75',
#  'Produto 76',
#  'Produto 77',
#  'Produto 78',
#  'Produto 79',
#  'Produto 80',
#  'Produto 81',
#  'Produto 82',
#  'Produto 83',
#  'Produto 84',
#  'Produto 85',
#  'Produto 86',
#  'Produto 87',
#  'Produto 88',
#  'Produto 89',
#  'Produto 90',
#  'Produto 91',
#  'Produto 92',
#  'Produto 93',
#  'Produto 94',
#  'Produto 95',
#  'Produto 96',
#  'Produto 97',
#  'Produto 98',
#  'Produto 99',
#  'Produto 100',
#  'Produto 101',
#  'Produto 102',
#  'Produto 103',
#  'Produto 104',
#  'Produto 105',
#  'Produto 106',
#  'Produto 107',
#  'Produto 108',
#  'Produto 109',
#  'Produto 110',
#  'Produto 111',
#  'Produto 112',
#  'Produto 113',
#  'Produto 114',
#  'Produto 115',
#  'Produto 116',
#  'Produto 117',
#  'Produto 118',
#  'Produto 119',
#  'Produto 120',
#  'Produto 121',
#  'Produto 122',
#  'Produto 123',
#  'Produto 124',
#  'Produto 125',
#  'Produto 126',
#  'Produto 127',
#  'Produto 128',
#  'Produto 129',
#  'Produto 130',
#  'Produto 131',
#  'Produto 132',
#  'Produto 133',
#  'Produto 134',
#  'Produto 135',
#  'Produto 136',
#  'Produto 137',
#  'Produto 138',
#  'Produto 139',
#  'Produto 140',
#  'Produto 141',
#  'Produto 142',
#  'Produto 143',
#  'Produto 144',
#  'Produto 145',
#  'Produto 146',
#  'Produto 147',
#  'Produto 148',
#  'Produto 149',
#  'Produto 150',
#  'Produto 151',
#  'Produto 152',
#  'Produto 153',
#  'Produto 154',
#  'Produto 155',
#  'Produto 156',
#  'Produto 157',
#  'Produto 158',
#  'Produto 159',
#  'Produto 160',
#  'Produto 161',
#  'Produto 162',
#  'Produto 163',
#  'Produto 164',
#  'Produto 165',
#  'Produto 166',
#  'Produto 167',
#  'Produto 168',
#  'Produto 169',
#  'Produto 170',
#  'Produto 171',
#  'Produto 172',
#  'Produto 173',
#  'Produto 174',
#  'Produto 175',
#  'Produto 176',
#  'Produto 177',
#  'Produto 178',
#  'Produto 179',
#  'Produto 180',
#  'Produto 181',
#  'Produto 182',
#  'Produto 183',
#  'Produto 184',
#  'Produto 185',
#  'Produto 186',
#  'Produto 187',
#  'Produto 188',
#  'Produto 189',
#  'Produto 190',
#  'Produto 191',
#  'Produto 192',
#  'Produto 193',
#  'Produto 194',
#  'Produto 195',
#  'Produto 196',
#  'Produto 197',
#  'Produto 198',
#  'Produto 199',
#  'Produto 200',
#  'Produto 201',
#  'Produto 202',
#  'Produto 203',
#  'Produto 204',
#  'Produto 205',
#  'Produto 206',
#  'Produto 207',
#  'Produto 208',
#  'Produto 209',
#  'Produto 210',
#  'Produto 211',
#  'Produto 212',
#  'Produto 213',
#  'Produto 214',
#  'Produto 215',
#  'Produto 216',
#  'Produto 217',
#  'Produto 218',
#  'Produto 219',
#  'Produto 220',
#  'Produto 221',
#  'Produto 222',
#  'Produto 223',
#  'Produto 224',
#  'Produto 225',
#  'Produto 226',
#  'Produto 227',
#  'Produto 228',
#  'Produto 229',
#  'Produto 230',
#  'Produto 231',
#  'Produto 232',
#  'Produto 233',
#  'Produto 234',
#  'Produto 235',
#  'Produto 236',
#  'Produto 237',
#  'Produto 238',
#  'Produto 239',
#  'Produto 240',
#  'Produto 241',
#  'Produto 242',
#  'Produto 243',
#  'Produto 244',
#  'Produto 245',
#  'Produto 246',
#  'Produto 247',
#  'Produto 248',
#  'Produto 249',
#  'Produto 250',
#  'Produto 251',
#  'Produto 252',
#  'Produto 253',
#  'Produto 254',
#  'Produto 255',
#  'Produto 256',
#  'Produto 257',
#  'Produto 258',
#  'Produto 259',
#  'Produto 260',
#  'Produto 261',
#  'Produto 262',
#  'Produto 263',
#  'Produto 264',
#  'Produto 265',
#  'Produto 266',
#  'Produto 267',
#  'Produto 268',
#  'Produto 269',
#  'Produto 270',
#  'Produto 271',
#  'Produto 272',
#  'Produto 273',
#  'Produto 274',
#  'Produto 275',
#  'Produto 276',
#  'Produto 277',
#  'Produto 278',
#  'Produto 279',
#  'Produto 280',
#  'Produto 281',
#  'Produto 282',
#  'Produto 283',
#  'Produto 284',
#  'Produto 285',
#  'Produto 286',
#  'Produto 287',
#  'Produto 288',
#  'Produto 289',
#  'Produto 290',
#  'Produto 291',
#  'Produto 292',
#  'Produto 293',
#  'Produto 294',
#  'Produto 295',
#  'Produto 296',
#  'Produto 297',
#  'Produto 298',
#  'Produto 299',
#  'Produto 300',
#  'Produto 301',
#  'Produto 302',
#  'Produto 303',
#  'Produto 304',
#  'Produto 305',
#  'Produto 306',
#  'Produto 307',
#  'Produto 308',
#  'Produto 309',
#  'Produto 310',
#  'Produto 311',
#  'Produto 312',
#  'Produto 313',
#  'Produto 314',
#  'Produto 315',
#  'Produto 316',
#  'Produto 317',
#  'Produto 318',
#  'Produto 319',
#  'Produto 320',
#  'Produto 321',
#  'Produto 322',
#  'Produto 323',
#  'Produto 324',
#  'Produto 325',
#  'Produto 326',
#  'Produto 327',
#  'Produto 328',
#  'Produto 329',
#  'Produto 330',
#  'Produto 331',
#  'Produto 332',
#  'Produto 333',
#  'Produto 334',
#  'Produto 335',
#  'Produto 336',
#  'Produto 337',
#  'Produto 338',
#  'Produto 339',
#  'Produto 340',
#  'Produto 341',
#  'Produto 342',
#  'Produto 343',
#  'Produto 344',
#  'Produto 345',
#  'Produto 346',
#  'Produto 347',
#  'Produto 348',
#  'Produto 349',
#  'Produto 350',
#  'Produto 351',
#  'Produto 352',
#  'Produto 353',
#  'Produto 354',
#  'Produto 355',
#  'Produto 356',
#  'Produto 357',
#  'Produto 358',
#  'Produto 359',
#  'Produto 360',
#  'Produto 361',
#  'Produto 362',
#  'Produto 363',
#  'Produto 364',
#  'Produto 365',
#  'Produto 366',
#  'Produto 367',
#  'Produto 368',
#  'Produto 369',
#  'Produto 370',
#  'Produto 371',
#  'Produto 372',
#  'Produto 373',
#  'Produto 374',
#  'Produto 375',
#  'Produto 376',
#  'Produto 377',
#  'Produto 378',
#  'Produto 379',
#  'Produto 380',
#  'Produto 381',
#  'Produto 382',
#  'Produto 383',
#  'Produto 384',
#  'Produto 385',
#  'Produto 386',
#  'Produto 387',
#  'Produto 388',
#  'Produto 389',
#  'Produto 390',
#  'Produto 391',
#  'Produto 392',
#  'Produto 393',
#  'Produto 394',
#  'Produto 395',
#  'Produto 396',
#  'Produto 397',
#  'Produto 398',
#  'Produto 399',
#  'Produto 400',
#  'Produto 401',
#  'Produto 402',
#  'Produto 403',
#  'Produto 404',
#  'Produto 405',
#  'Produto 406',
#  'Produto 407',
#  'Produto 408',
#  'Produto 409',
#  'Produto 410',
#  'Produto 411',
#  'Produto 412',
#  'Produto 413',
#  'Produto 414',
#  'Produto 415',
#  'Produto 416',
#  'Produto 417',
#  'Produto 418',
#  'Produto 419',
#  'Produto 420',
#  'Produto 421',
#  'Produto 422',
#  'Produto 423',
#  'Produto 424',
#  'Produto 425',
#  'Produto 426',
#  'Produto 427',
#  'Produto 428',
#  'Produto 429',
#  'Produto 430',
#  'Produto 431',
#  'Produto 432',
#  'Produto 433',
#  'Produto 434',
#  'Produto 435',
#  'Produto 436',
#  'Produto 437',
#  'Produto 438',
#  'Produto 439',
#  'Produto 440',
#  'Produto 441',
#  'Produto 442',
#  'Produto 443',
#  'Produto 444',
#  'Produto 445',
#  'Produto 446',
#  'Produto 447',
#  'Produto 448',
#  'Produto 449',
#  'Produto 450',
#  'Produto 451',
#  'Produto 452',
#  'Produto 453',
#  'Produto 454',
#  'Produto 455',
#  'Produto 456',
#  'Produto 457',
#  'Produto 458',
#  'Produto 459',
#  'Produto 460',
#  'Produto 461',
#  'Produto 462',
#  'Produto 463',
#  'Produto 464',
#  'Produto 465',
#  'Produto 466',
#  'Produto 467',
#  'Produto 468',
#  'Produto 469',
#  'Produto 470',
#  'Produto 471',
#  'Produto 472',
#  'Produto 473',
#  'Produto 474',
#  'Produto 475',
#  'Produto 476',
#  'Produto 477',
#  'Produto 478',
#  'Produto 479',
#  'Produto 480',
#  'Produto 481',
#  'Produto 482',
#  'Produto 483',
#  'Produto 484',
#  'Produto 485',
#  'Produto 486',
#  'Produto 487',
#  'Produto 488',
#  'Produto 489',
#  'Produto 490',
#  'Produto 491',
#  'Produto 492',
#  'Produto 493',
#  'Produto 494',
#  'Produto 495',
#  'Produto 496',
#  'Produto 497',
#  'Produto 498',
#  'Produto 499',
#  'Produto 500',
#  'Produto 501',
#  'Produto 502',
#  'Produto 503',
#  'Produto 504',
#  'Produto 505',
#  'Produto 506',
#  'Produto 507',
#  'Produto 508',
#  'Produto 509',
#  'Produto 510',
#  'Produto 511',
#  'Produto 512',
#  'Produto 513',
#  'Produto 514',
#  'Produto 515',
#  'Produto 516',
#  'Produto 517',
#  'Produto 518',
#  'Produto 519',
#  'Produto 520',
#  'Produto 521',
#  'Produto 522',
#  'Produto 523',
#  'Produto 524',
#  'Produto 525',
#  'Produto 526',
#  'Produto 527',
#  'Produto 528',
#  'Produto 529',
#  'Produto 530',
#  'Produto 531',
#  'Produto 532',
#  'Produto 533',
#  'Produto 534',
#  'Produto 535',
#  'Produto 536',
#  'Produto 537',
#  'Produto 538',
#  'Produto 539',
#  'Produto 540',
#  'Produto 541',
#  'Produto 542',
#  'Produto 543',
#  'Produto 544',
#  'Produto 545',
#  'Produto 546',
#  'Produto 547',
#  'Produto 548',
#  'Produto 549',
#  'Produto 550',
#  'Produto 551',
#  'Produto 552',
#  'Produto 553',
#  'Produto 554',
#  'Produto 555',
#  'Produto 556',
#  'Produto 557',
#  'Produto 558',
#  'Produto 559',
#  'Produto 560',
#  'Produto 561',
#  'Produto 562',
#  'Produto 563',
#  'Produto 564',
#  'Produto 565',
#  'Produto 566',
#  'Produto 567',
#  'Produto 568',
#  'Produto 569',
#  'Produto 570',
#  'Produto 571',
#  'Produto 572',
#  'Produto 573',
#  'Produto 574',
#  'Produto 575',
#  'Produto 576',
#  'Produto 577',
#  'Produto 578',
#  'Produto 579',
#  'Produto 580',
#  'Produto 581',
#  'Produto 582',
#  'Produto 583',
#  'Produto 584',
#  'Produto 585',
#  'Produto 586',
#  'Produto 587',
#  'Produto 588',
#  'Produto 589',
#  'Produto 590',
#  'Produto 591',
#  'Produto 592',
#  'Produto 593',
#  'Produto 594',
#  'Produto 595',
#  'Produto 596',
#  'Produto 597',
#  'Produto 598',
#  'Produto 599',
#  'Produto 600',
#  'Produto 601',
#  'Produto 602',
#  'Produto 603',
#  'Produto 604',
#  'Produto 605',
#  'Produto 606',
#  'Produto 607',
#  'Produto 608',
#  'Produto 609',
#  'Produto 610',
#  'Produto 611',
#  'Produto 612',
#  'Produto 613',
#  'Produto 614',
#  'Produto 615',
#  'Produto 616',
#  'Produto 617',
#  'Produto 618',
#  'Produto 619',
#  'Produto 620',
#  'Produto 621',
#  'Produto 622',
#  'Produto 623',
#  'Produto 624',
#  'Produto 625',
#  'Produto 626',
#  'Produto 627',
#  'Produto 628',
#  'Produto 629',
#  'Produto 630',
#  'Produto 631',
#  'Produto 632',
#  'Produto 633',
#  'Produto 634',
#  'Produto 635',
#  'Produto 636',
#  'Produto 637',
#  'Produto 638',
#  'Produto 639',
#  'Produto 640',
#  'Produto 641',
#  'Produto 642',
#  'Produto 643',
#  'Produto 644',
#  'Produto 645',
#  'Produto 646',
#  'Produto 647',
#  'Produto 648',
#  'Produto 649',
#  'Produto 650',
#  'Produto 651',
#  'Produto 652',
#  'Produto 653',
#  'Produto 654',
#  'Produto 655',
#  'Produto 656',
#  'Produto 657',
#  'Produto 658',
#  'Produto 659',
#  'Produto 660',
#  'Produto 661',
#  'Produto 662',
#  'Produto 663',
#  'Produto 664',
#  'Produto 665',
#  'Produto 666',
#  'Produto 667',
#  'Produto 668',
#  'Produto 669',
#  'Produto 670',
#  'Produto 671',
#  'Produto 672',
#  'Produto 673',
#  'Produto 674',
#  'Produto 675',
#  'Produto 676',
#  'Produto 677',
#  'Produto 678',
#  'Produto 679',
#  'Produto 680',
#  'Produto 681',
#  'Produto 682',
#  'Produto 683',
#  'Produto 684',
#  'Produto 685',
#  'Produto 686',
#  'Produto 687',
#  'Produto 688',
#  'Produto 689',
#  'Produto 690',
#  'Produto 691',
#  'Produto 692',
#  'Produto 693',
#  'Produto 694',
#  'Produto 695',
#  'Produto 696',
#  'Produto 697',
#  'Produto 698',
#  'Produto 699',
#  'Produto 700',
#  'Produto 701',
#  'Produto 702',
#  'Produto 703',
#  'Produto 704',
#  'Produto 705',
#  'Produto 706',
#  'Produto 707',
#  'Produto 708',
#  'Produto 709',
#  'Produto 710',
#  'Produto 711',
#  'Produto 712',
#  'Produto 713',
#  'Produto 714',
#  'Produto 715',
#  'Produto 716',
#  'Produto 717',
#  'Produto 718',
#  'Produto 719',
#  'Produto 720',
#  'Produto 721',
#  'Produto 722',
#  'Produto 723',
#  'Produto 724',
#  'Produto 725',
#  'Produto 726',
#  'Produto 727',
#  'Produto 728',
#  'Produto 729',
#  'Produto 730',
#  'Produto 731',
#  'Produto 732',
#  'Produto 733',
#  'Produto 734',
#  'Produto 735',
#  'Produto 736',
#  'Produto 737',
#  'Produto 738',
#  'Produto 739',
#  'Produto 740',
#  'Produto 741',
#  'Produto 742',
#  'Produto 743',
#  'Produto 744',
#  'Produto 745',
#  'Produto 746',
#  'Produto 747',
#  'Produto 748',
#  'Produto 749',
#  'Produto 750',
#  'Produto 751',
#  'Produto 752',
#  'Produto 753',
#  'Produto 754',
#  'Produto 755',
#  'Produto 756',
#  'Produto 757',
#  'Produto 758',
#  'Produto 759',
#  'Produto 760',
#  'Produto 761',
#  'Produto 762',
#  'Produto 763',
#  'Produto 764',
#  'Produto 765',
#  'Produto 766',
#  'Produto 767',
#  'Produto 768',
#  'Produto 769',
#  'Produto 770',
#  'Produto 771',
#  'Produto 772',
#  'Produto 773',
#  'Produto 774',
#  'Produto 775',
#  'Produto 776',
#  'Produto 777',
#  'Produto 778',
#  'Produto 779',
#  'Produto 780',
#  'Produto 781',
#  'Produto 782',
#  'Produto 783',
#  'Produto 784',
#  'Produto 785',
#  'Produto 786',
#  'Produto 787',
#  'Produto 788',
#  'Produto 789',
#  'Produto 790',
#  'Produto 791',
#  'Produto 792',
#  'Produto 793',
#  'Produto 794',
#  'Produto 795',
#  'Produto 796',
#  'Produto 797',
#  'Produto 798',
#  'Produto 799',
#  'Produto 800',
#  'Produto 801',
#  'Produto 802',
#  'Produto 803',
#  'Produto 804',
#  'Produto 805',
#  'Produto 806',
#  'Produto 807',
#  'Produto 808',
#  'Produto 809',
#  'Produto 810',
#  'Produto 811',
#  'Produto 812',
#  'Produto 813',
#  'Produto 814',
#  'Produto 815',
#  'Produto 816',
#  'Produto 817',
#  'Produto 818',
#  'Produto 819',
#  'Produto 820',
#  'Produto 821',
#  'Produto 822',
#  'Produto 823',
#  'Produto 824',
#  'Produto 825',
#  'Produto 826',
#  'Produto 827',
#  'Produto 828',
#  'Produto 829',
#  'Produto 830',
#  'Produto 831',
#  'Produto 832',
#  'Produto 833',
#  'Produto 834',
#  'Produto 835',
#  'Produto 836',
#  'Produto 837',
#  'Produto 838',
#  'Produto 839',
#  'Produto 840',
#  'Produto 841',
#  'Produto 842',
#  'Produto 843',
#  'Produto 844',
#  'Produto 845',
#  'Produto 846',
#  'Produto 847',
#  'Produto 848',
#  'Produto 849',
#  'Produto 850',
#  'Produto 851',
#  'Produto 852',
#  'Produto 853',
#  'Produto 854',
#  'Produto 855',
#  'Produto 856',
#  'Produto 857',
#  'Produto 858',
#  'Produto 859',
#  'Produto 860',
#  'Produto 861',
#  'Produto 862',
#  'Produto 863',
#  'Produto 864',
#  'Produto 865',
#  'Produto 866',
#  'Produto 867',
#  'Produto 868',
#  'Produto 869',
#  'Produto 870',
#  'Produto 871',
#  'Produto 872',
#  'Produto 873',
#  'Produto 874',
#  'Produto 875',
#  'Produto 876',
#  'Produto 877',
#  'Produto 878',
#  'Produto 879',
#  'Produto 880',
#  'Produto 881',
#  'Produto 882',
#  'Produto 883',
#  'Produto 884',
#  'Produto 885',
#  'Produto 886',
#  'Produto 887',
#  'Produto 888',
#  'Produto 889',
#  'Produto 890',
#  'Produto 891',
#  'Produto 892',
#  'Produto 893',
#  'Produto 894',
#  'Produto 895',
#  'Produto 896',
#  'Produto 897',
#  'Produto 898',
#  'Produto 899',
#  'Produto 900',
#  'Produto 901',
#  'Produto 902',
#  'Produto 903',
#  'Produto 904',
#  'Produto 905',
#  'Produto 906',
#  'Produto 907',
#  'Produto 908',
#  'Produto 909',
#  'Produto 910',
#  'Produto 911',
#  'Produto 912',
#  'Produto 913',
#  'Produto 914',
#  'Produto 915',
#  'Produto 916',
#  'Produto 917',
#  'Produto 918',
#  'Produto 919',
#  'Produto 920',
#  'Produto 921',
#  'Produto 922',
#  'Produto 923',
#  'Produto 924',
#  'Produto 925',
#  'Produto 926',
#  'Produto 927',
#  'Produto 928',
#  'Produto 929',
#  'Produto 930',
#  'Produto 931',
#  'Produto 932',
#  'Produto 933',
#  'Produto 934',
#  'Produto 935',
#  'Produto 936',
#  'Produto 937',
#  'Produto 938',
#  'Produto 939',
#  'Produto 940',
#  'Produto 941',
#  'Produto 942',
#  'Produto 943',
#  'Produto 944',
#  'Produto 945',
#  'Produto 946',
#  'Produto 947',
#  'Produto 948',
#  'Produto 949',
#  'Produto 950',
#  'Produto 951',
#  'Produto 952',
#  'Produto 953',
#  'Produto 954',
#  'Produto 955',
#  'Produto 956',
#  'Produto 957',
#  'Produto 958',
#  'Produto 959',
#  'Produto 960',
#  'Produto 961',
#  'Produto 962',
#  'Produto 963',
#  'Produto 964',
#  'Produto 965',
#  'Produto 966',
#  'Produto 967',
#  'Produto 968',
#  'Produto 969',
#  'Produto 970',
#  'Produto 971',
#  'Produto 972',
#  'Produto 973',
#  'Produto 974',
#  'Produto 975',
#  'Produto 976',
#  'Produto 977',
#  'Produto 978',
#  'Produto 979',
#  'Produto 980',
#  'Produto 981',
#  'Produto 982',
#  'Produto 983',
#  'Produto 984',
#  'Produto 985',
#  'Produto 986',
#  'Produto 987',
#  'Produto 988',
#  'Produto 989',
#  'Produto 990',
#  'Produto 991',
#  'Produto 992',
#  'Produto 993',
#  'Produto 994',
#  'Produto 995',
#  'Produto 996',
#  'Produto 997',
#  'Produto 998',
#  'Produto 999',
#  ...]

# %%
#validando se o valor de linhas está batendo
len(produtos_numerados)
# Out:
# 106823

# %%
#substituindo a coluna PRODUTOS pela lista de 'produtos_numrados'
#necessario que tenha o mesmo numero de valores (no caso, mesmo números de linhas)
df['PRODUTO'] = produtos_numerados
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# 2               MATO GROSSO       Produto 2                           192
# 3        MATO GROSSO DO SUL       Produto 3                           162
# 4                   ALAGOAS       Produto 4                           103
# ...                     ...             ...                           ...
# 106818  RIO GRANDE DO NORTE  Produto 106818                             7
# 106819    RIO GRANDE DO SUL  Produto 106819                            23
# 106820       SANTA CATARINA  Produto 106820                            24
# 106821            SAO PAULO  Produto 106821                            52
# 106822              SERGIPE  Produto 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
#a cópia permanece a mesma
df_produto
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
#retornando para valores originais com a Series na qual o copy() foi utilizado

df["PRODUTO"] = df_produto
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
#criando coluna com valor constante, aparece no último lugar
df['COL TESTE'] = 'default'
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  COL TESTE
# 0                              0.133   5  2004    default
# 1                              0.115   5  2004    default
# 2                              0.098   5  2004    default
# 3                              0.143   5  2004    default
# 4                              0.082   5  2004    default
# ...                              ...  ..   ...        ...
# 106818                             0   6  2019    default
# 106819                         0.164   6  2019    default
# 106820                             0   6  2019    default
# 106821                          0.07   6  2019    default
# 106822                             0   6  2019    default
#
# [106823 rows x 22 columns]

# %%
#criando coluna a partir de lista
#len(coluna) rpecisa bater com numero de linhas da tabela

df['Coluna a partir de lista'] = range(df.shape[0])
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        COL TESTE  Coluna a partir de lista
# 0        default                         0
# 1        default                         1
# 2        default                         2
# 3        default                         3
# 4        default                         4
# ...          ...                       ...
# 106818   default                    106818
# 106819   default                    106819
# 106820   default                    106820
# 106821   default                    106821
# 106822   default                    106822
#
# [106823 rows x 23 columns]

# %%
#coluna fazendo referencia a outra coluna

df['PRECO EM DOLARES'] = df['PREÇO MÉDIO REVENDA']*6
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COL TESTE  \
# 0                              0.133   5  2004   default
# 1                              0.115   5  2004   default
# 2                              0.098   5  2004   default
# 3                              0.143   5  2004   default
# 4                              0.082   5  2004   default
# ...                              ...  ..   ...       ...
# 106818                             0   6  2019   default
# 106819                         0.164   6  2019   default
# 106820                             0   6  2019   default
# 106821                          0.07   6  2019   default
# 106822                             0   6  2019   default
#
#        Coluna a partir de lista  PRECO EM DOLARES
# 0                             0             7.728
# 1                             1             6.972
# 2                             2             8.334
# 3                             3             7.572
# 4                             4             7.086
# ...                         ...               ...
# 106818                   106818            21.444
# 106819                   106819            20.406
# 106820                   106820            17.472
# 106821                   106821            18.120
# 106822                   106822            22.182
#
# [106823 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais observações (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma observação/linha:**

# %%
#seleção de uma linha
df.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# COL TESTE                                 default
# Coluna a partir de lista                        1
# PRECO EM DOLARES                            6.972
# Name: 1, dtype: object

# %%
#seleção de várias linha usando slice
#no caso, de 0 a 10
df.iloc[:10]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
# 6                1.453                  0.218  ...                       1.1
# 7                1.631                  0.158  ...                     1.116
# 8                1.284                  0.130  ...                     0.931
# 9                1.224                  0.141  ...                     0.947
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
# 6                       0.068                    0.7332
# 7                       0.091                    0.9923
# 8                       0.072                    0.7577
# 9                       0.091                    0.5643
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
# 6                      1.294                         0.062   5  2004
# 7                    1.36183                         0.082   5  2004
# 8                     1.2972                         0.077   5  2004
# 9                     1.3541                         0.096   5  2004
#
#   COL TESTE Coluna a partir de lista  PRECO EM DOLARES
# 0   default                        0             7.728
# 1   default                        1             6.972
# 2   default                        2             8.334
# 3   default                        3             7.572
# 4   default                        4             7.086
# 5   default                        5             8.298
# 6   default                        6             8.718
# 7   default                        7             9.786
# 8   default                        8             7.704
# 9   default                        9             7.344
#
# [10 rows x 24 columns]

# %%
#seleção de várias linhas, mas não sequenciais, usando listas

df.iloc[[1,5,10,15
        ]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 5                        0.128                    0.5686
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 5                        1.35                         0.134   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    COL TESTE Coluna a partir de lista  PRECO EM DOLARES
# 1    default                        1             6.972
# 5    default                        5             8.298
# 10   default                       10             9.438
# 15   default                       15             9.468
#
# [4 rows x 24 columns]

# %%
#pode ser passado fora de ordem

df.iloc[[1,10,15, 5
        ]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
# 5                 1.383                  0.132  ...                     0.957
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
# 5                        0.128                    0.5686
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
# 5                        1.35                         0.134   5  2004
#
#    COL TESTE Coluna a partir de lista  PRECO EM DOLARES
# 1    default                        1             6.972
# 10   default                       10             9.438
# 15   default                       15             9.468
# 5    default                        5             8.298
#
# [4 rows x 24 columns]

# %%
#localizando célula especifica
df.iloc[1,5]
# Out:
# 'ETANOL HIDRATADO'

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
#localizando usando os indices (mesmo com índices implícitos) = iloc
pesquisa_de_satisfacao.iloc[0,1]
# Out:
# np.int64(131)

# %%
#localizando usando os rótulos = loc
pesquisa_de_satisfacao.loc['XboxOne','ruim']
# Out:
# np.int64(131)

# %%
#filtrando: todas as linhas, mas só com as colunas 'ruim' e 'péssimo'
#intervalos vazios para selecionar tudo (ou 'desde o começo'; 'até o fim')
pesquisa_de_satisfacao.iloc[:, 1:]
# Out:
#               ruim  pessimo
# XboxOne        131       30
# Playstation4     2       20
# Switch          30        1

# %%
#se o df possui indíces, é possível capturar as linhas mesmo com loc
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   COL TESTE Coluna a partir de lista  PRECO EM DOLARES
# 0   default                        0             7.728
# 1   default                        1             6.972
# 2   default                        2             8.334
# 3   default                        3             7.572
# 4   default                        4             7.086
#
# [5 rows x 24 columns]

# %%
df.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# COL TESTE                                 default
# Coluna a partir de lista                        1
# PRECO EM DOLARES                            6.972
# Name: 1, dtype: object

# %%
#mas as colunas precisarão ser pelo nome
df.loc[1, 'PRECO EM DOLARES']
# Out:
# np.float64(6.9719999999999995)

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
df.loc[:5, 'ESTADO']
# Out:
# 0      DISTRITO FEDERAL
# 1                 GOIAS
# 2           MATO GROSSO
# 3    MATO GROSSO DO SUL
# 4               ALAGOAS
# 5                 BAHIA
# Name: ESTADO, dtype: object

# %%
#filtrar colunas: usar lista, retorna na ordem colocada
df[['ESTADO', 'DATA INICIAL']]
# Out:
#                      ESTADO DATA INICIAL
# 0          DISTRITO FEDERAL   2004-05-09
# 1                     GOIAS   2004-05-09
# 2               MATO GROSSO   2004-05-09
# 3        MATO GROSSO DO SUL   2004-05-09
# 4                   ALAGOAS   2004-05-09
# ...                     ...          ...
# 106818  RIO GRANDE DO NORTE   2019-06-23
# 106819    RIO GRANDE DO SUL   2019-06-23
# 106820       SANTA CATARINA   2019-06-23
# 106821            SAO PAULO   2019-06-23
# 106822              SERGIPE   2019-06-23
#
# [106823 rows x 2 columns]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
#deleta coluna a partir do nome
del df['Unnamed: 0']

# %%
#deletar múltiplas colunas: um del por linha
del df['COL TESTE']
del df['Coluna a partir de lista']

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PRECO EM DOLARES
# 0             7.728
# 1             6.972
# 2             8.334
# 3             7.572
# 4             7.086
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
# usar função df.to_csv()

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br> <br>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.
#
# Regras: Gasolina comum, preço acima de R$2,00; estar nos estados de SP ou RJ

# %%
df.head(1)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                  0.016                  1.19  ...                 0.463
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                    0.012                     0.825
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
#
#    PRECO EM DOLARES
# 0             7.728
#
# [1 rows x 21 columns]

# %%
filtro_1 = (df['ESTADO'] == 'SAO PAULO') | (df['ESTADO'] == 'RIO DE JANEIRO')
filtro_1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
#encontrar valores de PRODUTO
df['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
filtro_2 = df['PRODUTO'] == 'GASOLINA COMUM'
filtro_2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: PRODUTO, Length: 106823, dtype: bool

# %%
filtro_3 = df['PREÇO MÉDIO REVENDA'] > 2
filtro_3
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
filtro_final = filtro_1 & filtro_2 & filtro_3

#mostrar as linhas do df que correspondem às regras aplicadas nos filtros 1 a 3
df_filtrado = df[filtro_final]

# %%
#validando resultados == estados são apenas RJ e SP? Produto apenas Gasolina comum?

print(df_filtrado['ESTADO'].unique())
print(df_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %%
#validando resultados == valores apenas acima de R$2?
df_filtrado['PREÇO MÉDIO REVENDA'].min()
# Out:
# 2.028

# %% [markdown]
# Alternativa mais performática: salva df temporarios para que as filtragens ocorram em uma quantidade menor de linhas

# %%
filtro_1 = (df['ESTADO'] == 'SAO PAULO') | (df['ESTADO'] == 'RIO DE JANEIRO')
postos_sprj = df[filtro_1]

filtro_2 = df["PRODUTO"] == 'GASOLINA COMUM'
produto_gasolinacomum_sprj = postos_sprj[filtro_2]

filtro_3 = df['PREÇO MÁXIMO REVENDA'] > 2
produto_acima2reais_gasolina_comum_sprj = produto_gasolinacomum_sprj[filtro_3]
# Out:
# /tmp/ipython-input-1783691464.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   produto_gasolinacomum_sprj = postos_sprj[filtro_2]
# /tmp/ipython-input-1783691464.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   produto_acima2reais_gasolina_comum_sprj = produto_gasolinacomum_sprj[filtro_3]

# %%
produto_acima2reais_gasolina_comum_sprj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12087                           4107              R$/l                1.891
# 12113                           1055              R$/l                2.040
# 12114                           4133              R$/l                1.888
# 12140                           1091              R$/l                2.042
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12087                   0.101                 1.570  ...
# 12113                   0.113                 1.700  ...
# 12114                   0.101                 1.540  ...
# 12140                   0.108                 1.700  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 12086                  0.254                    0.053
# 12087                  0.235                    0.053
# 12113                  0.252                    0.055
# 12114                  0.233                    0.053
# 12140                  0.252                    0.053
# ...                      ...                      ...
# 106479                 0.425                    0.042
# 106623                 0.544                    0.032
# 106629                 0.443                    0.042
# 106772                 0.538                    0.033
# 106778                 0.429                    0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12087                      1.656                      0.064
# 12113                      1.788                      0.049
# 12114                      1.655                      0.063
# 12140                       1.79                      0.046
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12087                       1.38                     1.944
# 12113                     1.5943                   1.99651
# 12114                       1.38                    1.9319
# 12140                    1.63596                    2.2137
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PRECO EM DOLARES
# 12086                          0.026   5  2004            12.270
# 12087                          0.039   5  2004            11.346
# 12113                          0.027   5  2004            12.240
# 12114                          0.038   5  2004            11.328
# 12140                          0.026   5  2004            12.252
# ...                              ...  ..   ...               ...
# 106479                         0.025   6  2019            25.260
# 106623                         0.023   6  2019            29.562
# 106629                         0.026   6  2019            25.008
# 106772                         0.022   6  2019            29.568
# 106778                         0.026   6  2019            24.852
#
# [1570 rows x 21 columns]

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de São Paulo.

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %% [markdown]
# <br/>
#
# Alternativamente:

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao_anos = (df['ANO'] == 2008) | (df['ANO'] == 2010) | (df['ANO'] == 2012)
df[selecao_anos]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 5098                   0.29                    0.045
# 5099                  0.293                    0.062
# 5100                  0.278                    0.060
# 5101                  0.382                    0.025
# 5102                  0.199                    0.058
# ...                     ...                      ...
# 55754                 0.466                    0.008
# 55755                 0.566                    0.020
# 55756                     -                    0.017
# 55757                 0.397                    0.125
# 55758                 0.504                    0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PRECO EM DOLARES
# 5098                           0.04   1  2008            10.836
# 5099                          0.038   1  2008             9.696
# 5100                          0.056   1  2008             9.486
# 5101                           0.03   1  2008            10.986
# 5102                          0.041   1  2008            10.194
# ...                             ...  ..   ...               ...
# 55754                         0.069  12  2012            11.346
# 55755                          0.02  12  2012            11.880
# 55756                             -  12  2012            12.018
# 55757                         0.152  12  2012             9.588
# 55758                         0.133  12  2012            11.082
#
# [19576 rows x 21 columns]

# %%
#validando seleção
df[selecao_anos]['ANO'].unique()
# Out:
# array([2008, 2010, 2012])

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008,2010,2012]

# %%
df['ANO'].isin(lista_de_anos)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
validando_lista = df['ANO'].isin(lista_de_anos)
df[validando_lista]['ANO'].unique()
# Out:
# array([2008, 2010, 2012])

# %% [markdown]
# Alternativa 3: usando query

# %%
df.query('ANO in @lista_de_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 5098                   0.29                    0.045
# 5099                  0.293                    0.062
# 5100                  0.278                    0.060
# 5101                  0.382                    0.025
# 5102                  0.199                    0.058
# ...                     ...                      ...
# 55754                 0.466                    0.008
# 55755                 0.566                    0.020
# 55756                     -                    0.017
# 55757                 0.397                    0.125
# 55758                 0.504                    0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PRECO EM DOLARES
# 5098                           0.04   1  2008            10.836
# 5099                          0.038   1  2008             9.696
# 5100                          0.056   1  2008             9.486
# 5101                           0.03   1  2008            10.986
# 5102                          0.041   1  2008            10.194
# ...                             ...  ..   ...               ...
# 55754                         0.069  12  2012            11.346
# 55755                          0.02  12  2012            11.880
# 55756                             -  12  2012            12.018
# 55757                         0.152  12  2012             9.588
# 55758                         0.133  12  2012            11.082
#
# [19576 rows x 21 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
#importante! rever isso aqui

for index, row in df.head().iterrows():
  print(f"indice {index} : {row['ESTADO']}")
# Out:
# indice 0 : DISTRITO FEDERAL
# indice 1 : GOIAS
# indice 2 : MATO GROSSO
# indice 3 : MATO GROSSO DO SUL
# indice 4 : ALAGOAS

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %% [markdown]
# #### **Dados Numéricos**

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %% [markdown]
# #### Quais são os estados considerados?

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='https://github.com/julianavtal/pandas-essencial/blob/main/imagens/apply_map_applymap.png?raw=1' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='https://github.com/julianavtal/pandas-essencial/blob/main/imagens/pandas_axis.jpg?raw=1' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %% [markdown]
# <img src='https://github.com/julianavtal/pandas-essencial/blob/main/imagens/apply_axis_1.png?raw=1' width=250/>

# %% [markdown]
# <img src='https://github.com/julianavtal/pandas-essencial/blob/main/imagens/apply_axis_0.png?raw=1' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %% [markdown]
# <img src='https://github.com/julianavtal/pandas-essencial/blob/main/imagens/apply_axis_1_mean.png?raw=1' width=350/>

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                  columns=['A', 'B', 'C'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3186067447.py in <cell line: 0>()
#       2                    [4, 5, 6],
#       3                    [7, 8, 9],
# ----> 4                    [np.nan, np.nan, np.nan]],
#       5                   columns=['A', 'B', 'C'])
#       6 df
#
# NameError: name 'np' is not defined

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %% [markdown]
# #### **Estatísticas Descritivas**

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
